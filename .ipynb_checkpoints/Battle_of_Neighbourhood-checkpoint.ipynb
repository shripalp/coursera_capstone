# %% [markdown]
# # This Notebook is for Capstone Project from Coursera IBM Data Science Professional Certificate Course

# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
#import Calgary neighbourhood coordinates
url ='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_T'

# %%
#rscrape website and load to Pandas dataframe
dfs = pd.read_html(url)

#get the table into data-frame
df_calgary = dfs[1]
df_calgary.head(16)
# Out:
#    Postal Code         Borough  \
# 0          T1A    Medicine Hat
# 1          T2A         Calgary
# 2          T3A         Calgary
# 3          T4A         Airdrie
# 4          T5A        Edmonton
# 5          T6A        Edmonton
# 6          T7A  Drayton Valley
# 7          T8A   Sherwood Park
# 8          T9A      Wetaskiwin
# 9          T1B    Medicine Hat
# 10         T2B         Calgary
# 11         T3B         Calgary
# 12         T4B         Airdrie
# 13         T5B        Edmonton
# 14         T6B        Edmonton
# 15         T7B    Not assigned
#
#                                          Neighborhood      Latitude  \
# 0                                Central Medicine Hat     50.036460
# 1                      Penbrooke Meadows, Marlborough     51.049680
# 2        Dalhousie, Edgemont, Hamptons, Hidden Valley     51.126060
# 3                                        East Airdrie     51.272450
# 4                    West Clareview, East Londonderry       53.5899
# 5                                      North Capilano       53.5483
# 6                                        Not assigned       53.2165
# 7                                  West Sherwood Park        53.519
# 8                                        Not assigned       52.9741
# 9                                  South Medicine Hat       50.0172
# 10                     Forest Lawn, Dover, Erin Woods       51.0318
# 11     Montgomery, Bowness, Silver Springs, Greenwood       51.0809
# 12                                       West Airdrie       51.2816
# 13                   East North Central, West Beverly       53.5766
# 14  SE Capilano, West Southeast Industrial, East B...       53.5322
# 15                                       Not assigned  Not assigned
#
#        Longitude
# 0    -110.679250
# 1    -113.964320
# 2    -114.143158
# 3    -113.986980
# 4      -113.4413
# 5       -113.408
# 6      -114.9893
# 7      -113.3216
# 8      -113.3646
# 9       -110.651
# 10     -113.9786
# 11     -114.1616
# 12     -114.0153
# 13     -113.4608
# 14     -113.4404
# 15  Not assigned

# %%
df_calgary.rename(columns = {'Postal Code': 'PostalCode'}, inplace = True)
df_calgary.head()
# Out:
#   PostalCode       Borough                                  Neighborhood  \
# 0        T1A  Medicine Hat                          Central Medicine Hat
# 1        T2A       Calgary                Penbrooke Meadows, Marlborough
# 2        T3A       Calgary  Dalhousie, Edgemont, Hamptons, Hidden Valley
# 3        T4A       Airdrie                                  East Airdrie
# 4        T5A      Edmonton              West Clareview, East Londonderry
#
#     Latitude    Longitude
# 0  50.036460  -110.679250
# 1  51.049680  -113.964320
# 2  51.126060  -114.143158
# 3  51.272450  -113.986980
# 4    53.5899    -113.4413

# %%
df_calgary.shape
# Out:
# (180, 5)

# %%
indexNames = df_calgary[ (df_calgary['Borough'] != 'Calgary')].index
df_calgary.drop(indexNames, inplace = True)

df_calgary = df_calgary.reset_index(drop=True)

df_calgary.head()
# Out:
#   PostalCode  Borough                                       Neighborhood  \
# 0        T2A  Calgary                     Penbrooke Meadows, Marlborough
# 1        T3A  Calgary       Dalhousie, Edgemont, Hamptons, Hidden Valley
# 2        T2B  Calgary                     Forest Lawn, Dover, Erin Woods
# 3        T3B  Calgary     Montgomery, Bowness, Silver Springs, Greenwood
# 4        T2C  Calgary  Lynnwood Ridge, Ogden, Foothills Industrial, G...
#
#     Latitude    Longitude
# 0  51.049680  -113.964320
# 1  51.126060  -114.143158
# 2    51.0318    -113.9786
# 3    51.0809    -114.1616
# 4    50.9878    -114.0001

# %%
df_calgary.shape
# Out:
# (35, 5)

# %%
#drop rows of data where Borough and Neighbourhood not assigned to postal code
indexNames = df_calgary[(df_calgary['Latitude'] == 'Not assigned')].index
df_calgary.drop(indexNames, inplace = True)

df_calgary = df_calgary.reset_index(drop=True)

df_calgary.head()
# Out:
#   PostalCode  Borough                                       Neighborhood  \
# 0        T2A  Calgary                     Penbrooke Meadows, Marlborough
# 1        T3A  Calgary       Dalhousie, Edgemont, Hamptons, Hidden Valley
# 2        T2B  Calgary                     Forest Lawn, Dover, Erin Woods
# 3        T3B  Calgary     Montgomery, Bowness, Silver Springs, Greenwood
# 4        T2C  Calgary  Lynnwood Ridge, Ogden, Foothills Industrial, G...
#
#     Latitude    Longitude
# 0  51.049680  -113.964320
# 1  51.126060  -114.143158
# 2    51.0318    -113.9786
# 3    51.0809    -114.1616
# 4    50.9878    -114.0001

# %%
df_calgary.shape
# Out:
# (34, 5)

# %%
df = pd.read_csv('calgary_data.csv')

# %%
df.shape
# Out:
# (306, 18)

# %%
x = (df['NAME'].str.startswith('0')) | (df['NAME'].str.startswith('1'))

# %%
df['TEMPORARY'] = x

# %%
df.shape
# Out:
# (306, 19)

# %%
indexNames = df[(df['TEMPORARY'] == True)].index
df.drop(indexNames, inplace = True)

df = df.reset_index(drop=True)

df.shape
# Out:
# (258, 19)

# %%
df.head(15)
# Out:
#           CLASS  CLASS_CODE                          NAME     SECTOR  RES_CNT  \
# 0   Residential           1                        LEGACY      SOUTH     6420
# 1   Residential           1                 HIGHLAND PARK     CENTRE     3838
# 2   Residential           1                   CORNERSTONE  NORTHEAST     2648
# 3   Residential           1                    MONTGOMERY  NORTHWEST     4515
# 4   Residential           1                        TEMPLE  NORTHEAST    10977
# 5   Residential           1                      WOODBINE      SOUTH     8866
# 6   Residential           1            UNIVERSITY HEIGHTS  NORTHWEST     2921
# 7   Residential           1                      BANKVIEW     CENTRE     5256
# 8   Residential           1  ALBERT PARK/RADISSON HEIGHTS       EAST     6997
# 9    Industrial           2                  GREAT PLAINS       EAST        0
# 10  Residential           1                  KELVIN GROVE      SOUTH     2305
# 11   Industrial           2                      STONEY 2  NORTHEAST        0
# 12  Residential           1                  WEST SPRINGS       WEST    10758
# 13  Residential           1                       BAYVIEW      SOUTH      751
# 14  Residential           1                    SHAGANAPPI     CENTRE     1626
#
#     DWELL_CNT  OWNSHP_CNT  SING_FAMLY  DUPLEX  MULTI_PLEX  APARTMENT  \
# 0        2766        1826        1081     356          14       1004
# 1        2277         645         823     402          45        520
# 2        1285         708         595     264          69        219
# 3        2013        1027         987     539          10        132
# 4        3733        2460        2304     609           1        117
# 5        3372        2959        2930      82           0          0
# 6        1378         378         429      43           0        874
# 7        3531         826         483     115          50       2443
# 8        3010         819         909     474          27        794
# 9           0           0           0       0           0          0
# 10        903         426         354      16           0        505
# 11          7           0           0       0           0          0
# 12       3856        2960        2605     186          34        395
# 13        248         236         212       0           0          0
# 14        855         338         367     127           8        228
#
#     TOWN_HOUSE  MALE_CNT  FEMALE_CNT  MF_20_24  MF_25_34  MF_35_44  MF_45_54  \
# 0          311      3125        3283       418      1518      1204       724
# 1           24      1986        1846       217       777       798       485
# 2          128      1409        1225       125       607       593       261
# 3          111      2216        2291       317      1003       786       530
# 4          424      5597        5357       702      1616      1727      1303
# 5          342      4471        4373       466       969      1133      1214
# 6           12      1488        1427       547       691       350       248
# 7          244      2686        2553       396      1868      1172       604
# 8          346      3627        3360       418      1434      1220       885
# 9            0         0           0         0         0         0         0
# 10          26      1037        1265        98       230       353       225
# 11           0         0           0         0         0         0         0
# 12         634      5274        5444       411       905      2057      2034
# 13          36       359         392        45        40        99        95
# 14          38       817         800       135       450       288       185
#
#     TEMPORARY
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False

# %%
df.shape
# Out:
# (258, 19)

# %%
df.drop('TEMPORARY', axis = 1, inplace =True)

# %%
df.head()
# Out:
#          CLASS  CLASS_CODE           NAME     SECTOR  RES_CNT  DWELL_CNT  \
# 0  Residential           1         LEGACY      SOUTH     6420       2766
# 1  Residential           1  HIGHLAND PARK     CENTRE     3838       2277
# 2  Residential           1    CORNERSTONE  NORTHEAST     2648       1285
# 3  Residential           1     MONTGOMERY  NORTHWEST     4515       2013
# 4  Residential           1         TEMPLE  NORTHEAST    10977       3733
#
#    OWNSHP_CNT  SING_FAMLY  DUPLEX  MULTI_PLEX  APARTMENT  TOWN_HOUSE  \
# 0        1826        1081     356          14       1004         311
# 1         645         823     402          45        520          24
# 2         708         595     264          69        219         128
# 3        1027         987     539          10        132         111
# 4        2460        2304     609           1        117         424
#
#    MALE_CNT  FEMALE_CNT  MF_20_24  MF_25_34  MF_35_44  MF_45_54
# 0      3125        3283       418      1518      1204       724
# 1      1986        1846       217       777       798       485
# 2      1409        1225       125       607       593       261
# 3      2216        2291       317      1003       786       530
# 4      5597        5357       702      1616      1727      1303

# %%
sum_col = df['MF_20_24']+df['MF_25_34']+df['MF_35_44']+df['MF_45_54']
df['CLIENTS'] = sum_col

# %%
df.head()
# Out:
#          CLASS  CLASS_CODE           NAME     SECTOR  RES_CNT  DWELL_CNT  \
# 0  Residential           1         LEGACY      SOUTH     6420       2766
# 1  Residential           1  HIGHLAND PARK     CENTRE     3838       2277
# 2  Residential           1    CORNERSTONE  NORTHEAST     2648       1285
# 3  Residential           1     MONTGOMERY  NORTHWEST     4515       2013
# 4  Residential           1         TEMPLE  NORTHEAST    10977       3733
#
#    OWNSHP_CNT  SING_FAMLY  DUPLEX  MULTI_PLEX  APARTMENT  TOWN_HOUSE  \
# 0        1826        1081     356          14       1004         311
# 1         645         823     402          45        520          24
# 2         708         595     264          69        219         128
# 3        1027         987     539          10        132         111
# 4        2460        2304     609           1        117         424
#
#    MALE_CNT  FEMALE_CNT  MF_20_24  MF_25_34  MF_35_44  MF_45_54  CLIENTS
# 0      3125        3283       418      1518      1204       724     3864
# 1      1986        1846       217       777       798       485     2277
# 2      1409        1225       125       607       593       261     1586
# 3      2216        2291       317      1003       786       530     2636
# 4      5597        5357       702      1616      1727      1303     5348

# %%
df.drop(['MF_20_24','MF_25_34','MF_35_44','MF_45_54'], axis=1, inplace=True)

# %%
df.head()
# Out:
#          CLASS  CLASS_CODE           NAME     SECTOR  RES_CNT  DWELL_CNT  \
# 0  Residential           1         LEGACY      SOUTH     6420       2766
# 1  Residential           1  HIGHLAND PARK     CENTRE     3838       2277
# 2  Residential           1    CORNERSTONE  NORTHEAST     2648       1285
# 3  Residential           1     MONTGOMERY  NORTHWEST     4515       2013
# 4  Residential           1         TEMPLE  NORTHEAST    10977       3733
#
#    OWNSHP_CNT  SING_FAMLY  DUPLEX  MULTI_PLEX  APARTMENT  TOWN_HOUSE  \
# 0        1826        1081     356          14       1004         311
# 1         645         823     402          45        520          24
# 2         708         595     264          69        219         128
# 3        1027         987     539          10        132         111
# 4        2460        2304     609           1        117         424
#
#    MALE_CNT  FEMALE_CNT  CLIENTS
# 0      3125        3283     3864
# 1      1986        1846     2277
# 2      1409        1225     1586
# 3      2216        2291     2636
# 4      5597        5357     5348
